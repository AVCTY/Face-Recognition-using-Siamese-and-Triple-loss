# %% [markdown]
# # Face Recognition with Siamese Network
#
# In this project, we explore face recognition using a Siamese Neural Network. Siamese Networks are well-suited for this task, as they are designed to learn similarities between pairs of data points, making them ideal for recognizing faces in different scenarios.

# %% [markdown]
# A Siamese network include several, typically two or three, backbone neural networks which share weights. There are different loss functions that have been proposed for training a Siamese network, and the two commonly used ones are **triplet loss** and **contrastive loss**.
#
# <img src='https://www.researchgate.net/profile/Benyamin-Ghojogh/publication/347038642/figure/fig1/AS:969358884995072@1608124576765/Siamese-network-with-a-contrastive-and-b-triplet-loss-functions.png'>
#
#
# - **Triplet Loss**: is frequently used in face recognition and in-person re-identification.
# - **Contrastive Loss**: is used in similarity learning, image retrieval, and in recommendations systems.
#
# Therefore triplet loss is what we are going to be using for our facial recognition model.

# %% [markdown]
# The model is going to be trained on google colab and its free T4 GPU. The resources used which are the dataset, will be stored on google drive, and checkpoints during training and the final model will be saved to drive as well.

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing Libraries

# %%
import os
import zipfile

import random
import math
from tqdm import tqdm

import cv2
import numpy as np
import matplotlib.pyplot as plt
import shutil

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Flatten, Dense,\
                                    Dropout, BatchNormalization, Input
from tensorflow.keras.metrics import Mean, CosineSimilarity
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import EfficientNetB7, preprocess_input

print(tf.version.VERSION)
# Out:
# 2.14.0

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/Facial Recognition with Siamese Network/dataset.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/Face Data/Face Dataset/263/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/263/8.jpg
#    creating: /content/dataset/Face Data/Face Dataset/264/
#   inflating: /content/dataset/Face Data/Face Dataset/264/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/264/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/265/
#   inflating: /content/dataset/Face Data/Face Dataset/265/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/265/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/266/
#   inflating: /content/dataset/Face Data/Face Dataset/266/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/266/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/266/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/266/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/266/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/266/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/267/
#   inflating: /content/dataset/Face Data/Face Dataset/267/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/267/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/268/
#   inflating: /content/dataset/Face Data/Face Dataset/268/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/268/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/268/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/268/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/268/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/269/
#   inflating: /content/dataset/Face Data/Face Dataset/269/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/269/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/269/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/269/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/27/
#   inflating: /content/dataset/Face Data/Face Dataset/27/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/27/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/27/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/27/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/27/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/270/
#   inflating: /content/dataset/Face Data/Face Dataset/270/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/270/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/270/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/271/
#   inflating: /content/dataset/Face Data/Face Dataset/271/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/271/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/272/
#   inflating: /content/dataset/Face Data/Face Dataset/272/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/272/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/272/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/272/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/272/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/273/
#   inflating: /content/dataset/Face Data/Face Dataset/273/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/273/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/274/
#   inflating: /content/dataset/Face Data/Face Dataset/274/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/274/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/275/
#   inflating: /content/dataset/Face Data/Face Dataset/275/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/275/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/275/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/276/
#   inflating: /content/dataset/Face Data/Face Dataset/276/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/276/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/277/
#   inflating: /content/dataset/Face Data/Face Dataset/277/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/277/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/277/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/277/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/278/
#   inflating: /content/dataset/Face Data/Face Dataset/278/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/278/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/278/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/278/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/278/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/279/
#   inflating: /content/dataset/Face Data/Face Dataset/279/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/279/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/28/
#   inflating: /content/dataset/Face Data/Face Dataset/28/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/28/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/280/
#   inflating: /content/dataset/Face Data/Face Dataset/280/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/280/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/280/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/280/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/281/
#   inflating: /content/dataset/Face Data/Face Dataset/281/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/281/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/281/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/281/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/281/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/281/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/282/
#   inflating: /content/dataset/Face Data/Face Dataset/282/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/282/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/283/
#   inflating: /content/dataset/Face Data/Face Dataset/283/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/283/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/283/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/283/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/284/
#   inflating: /content/dataset/Face Data/Face Dataset/284/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/284/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/284/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/284/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/285/
#   inflating: /content/dataset/Face Data/Face Dataset/285/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/285/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/286/
#   inflating: /content/dataset/Face Data/Face Dataset/286/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/286/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/287/
#   inflating: /content/dataset/Face Data/Face Dataset/287/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/287/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/288/
#   inflating: /content/dataset/Face Data/Face Dataset/288/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/288/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/289/
#   inflating: /content/dataset/Face Data/Face Dataset/289/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/289/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/29/
#   inflating: /content/dataset/Face Data/Face Dataset/29/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/29/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/29/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/29/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/29/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/290/
#   inflating: /content/dataset/Face Data/Face Dataset/290/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/290/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/291/
#   inflating: /content/dataset/Face Data/Face Dataset/291/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/291/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/292/
#   inflating: /content/dataset/Face Data/Face Dataset/292/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/292/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/293/
#   inflating: /content/dataset/Face Data/Face Dataset/293/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/293/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/294/
#   inflating: /content/dataset/Face Data/Face Dataset/294/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/294/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/294/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/295/
#   inflating: /content/dataset/Face Data/Face Dataset/295/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/295/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/296/
#   inflating: /content/dataset/Face Data/Face Dataset/296/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/296/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/296/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/296/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/296/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/297/
#   inflating: /content/dataset/Face Data/Face Dataset/297/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/297/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/297/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/298/
#   inflating: /content/dataset/Face Data/Face Dataset/298/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/298/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/299/
#   inflating: /content/dataset/Face Data/Face Dataset/299/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/299/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/3/
#   inflating: /content/dataset/Face Data/Face Dataset/3/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/3/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/3/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/3/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/30/
#   inflating: /content/dataset/Face Data/Face Dataset/30/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/30/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/300/
#   inflating: /content/dataset/Face Data/Face Dataset/300/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/300/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/300/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/300/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/300/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/301/
#   inflating: /content/dataset/Face Data/Face Dataset/301/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/301/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/301/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/301/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/302/
#   inflating: /content/dataset/Face Data/Face Dataset/302/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/302/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/302/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/302/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/302/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/303/
#   inflating: /content/dataset/Face Data/Face Dataset/303/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/303/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/303/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/304/
#   inflating: /content/dataset/Face Data/Face Dataset/304/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/304/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/304/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/304/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/304/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/304/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/305/
#   inflating: /content/dataset/Face Data/Face Dataset/305/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/305/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/305/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/305/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/305/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/305/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/306/
#   inflating: /content/dataset/Face Data/Face Dataset/306/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/306/8.jpg
#    creating: /content/dataset/Face Data/Face Dataset/307/
#   inflating: /content/dataset/Face Data/Face Dataset/307/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/307/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/308/
#   inflating: /content/dataset/Face Data/Face Dataset/308/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/308/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/308/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/308/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/308/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/309/
#   inflating: /content/dataset/Face Data/Face Dataset/309/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/20.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/21.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/22.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/23.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/24.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/25.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/26.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/27.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/28.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/29.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/30.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/31.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/32.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/33.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/34.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/35.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/36.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/37.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/38.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/39.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/40.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/41.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/42.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/43.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/44.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/45.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/46.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/47.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/48.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/49.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/309/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/31/
#   inflating: /content/dataset/Face Data/Face Dataset/31/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/31/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/310/
#   inflating: /content/dataset/Face Data/Face Dataset/310/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/310/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/310/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/310/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/311/
#   inflating: /content/dataset/Face Data/Face Dataset/311/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/311/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/311/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/312/
#   inflating: /content/dataset/Face Data/Face Dataset/312/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/312/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/313/
#   inflating: /content/dataset/Face Data/Face Dataset/313/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/313/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/313/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/314/
#   inflating: /content/dataset/Face Data/Face Dataset/314/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/314/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/314/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/315/
#   inflating: /content/dataset/Face Data/Face Dataset/315/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/315/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/316/
#   inflating: /content/dataset/Face Data/Face Dataset/316/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/316/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/316/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/316/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/316/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/316/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/317/
#   inflating: /content/dataset/Face Data/Face Dataset/317/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/317/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/318/
#   inflating: /content/dataset/Face Data/Face Dataset/318/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/318/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/319/
#   inflating: /content/dataset/Face Data/Face Dataset/319/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/319/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/32/
#   inflating: /content/dataset/Face Data/Face Dataset/32/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/32/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/32/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/32/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/32/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/32/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/320/
#   inflating: /content/dataset/Face Data/Face Dataset/320/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/320/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/320/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/320/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/320/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/321/
#   inflating: /content/dataset/Face Data/Face Dataset/321/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/321/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/322/
#   inflating: /content/dataset/Face Data/Face Dataset/322/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/322/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/322/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/322/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/323/
#   inflating: /content/dataset/Face Data/Face Dataset/323/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/323/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/324/
#   inflating: /content/dataset/Face Data/Face Dataset/324/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/324/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/325/
#   inflating: /content/dataset/Face Data/Face Dataset/325/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/325/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/325/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/325/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/326/
#   inflating: /content/dataset/Face Data/Face Dataset/326/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/326/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/327/
#   inflating: /content/dataset/Face Data/Face Dataset/327/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/327/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/328/
#   inflating: /content/dataset/Face Data/Face Dataset/328/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/328/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/328/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/329/
#   inflating: /content/dataset/Face Data/Face Dataset/329/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/329/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/329/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/329/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/33/
#   inflating: /content/dataset/Face Data/Face Dataset/33/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/33/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/330/
#   inflating: /content/dataset/Face Data/Face Dataset/330/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/330/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/330/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/331/
#   inflating: /content/dataset/Face Data/Face Dataset/331/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/331/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/332/
#   inflating: /content/dataset/Face Data/Face Dataset/332/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/332/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/333/
#   inflating: /content/dataset/Face Data/Face Dataset/333/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/333/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/334/
#   inflating: /content/dataset/Face Data/Face Dataset/334/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/334/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/335/
#   inflating: /content/dataset/Face Data/Face Dataset/335/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/335/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/336/
#   inflating: /content/dataset/Face Data/Face Dataset/336/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/336/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/336/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/337/
#   inflating: /content/dataset/Face Data/Face Dataset/337/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/337/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/337/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/337/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/337/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/338/
#   inflating: /content/dataset/Face Data/Face Dataset/338/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/20.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/21.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/22.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/23.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/24.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/25.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/26.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/27.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/28.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/29.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/30.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/338/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/339/
#   inflating: /content/dataset/Face Data/Face Dataset/339/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/339/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/34/
#   inflating: /content/dataset/Face Data/Face Dataset/34/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/34/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/340/
#   inflating: /content/dataset/Face Data/Face Dataset/340/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/340/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/341/
#   inflating: /content/dataset/Face Data/Face Dataset/341/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/341/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/341/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/342/
#   inflating: /content/dataset/Face Data/Face Dataset/342/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/342/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/343/
#   inflating: /content/dataset/Face Data/Face Dataset/343/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/343/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/344/
#   inflating: /content/dataset/Face Data/Face Dataset/344/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/344/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/345/
#   inflating: /content/dataset/Face Data/Face Dataset/345/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/345/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/345/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/345/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/345/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/346/
#   inflating: /content/dataset/Face Data/Face Dataset/346/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/346/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/346/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/346/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/347/
#   inflating: /content/dataset/Face Data/Face Dataset/347/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/347/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/348/
#   inflating: /content/dataset/Face Data/Face Dataset/348/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/348/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/349/
#   inflating: /content/dataset/Face Data/Face Dataset/349/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/349/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/35/
#   inflating: /content/dataset/Face Data/Face Dataset/35/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/35/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/35/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/35/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/350/
#   inflating: /content/dataset/Face Data/Face Dataset/350/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/350/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/351/
#   inflating: /content/dataset/Face Data/Face Dataset/351/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/351/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/352/
#   inflating: /content/dataset/Face Data/Face Dataset/352/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/352/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/352/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/352/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/353/
#   inflating: /content/dataset/Face Data/Face Dataset/353/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/353/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/353/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/353/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/353/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/354/
#   inflating: /content/dataset/Face Data/Face Dataset/354/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/354/6.jpg
#    creating: /content/dataset/Face Data/Face Dataset/355/
#   inflating: /content/dataset/Face Data/Face Dataset/355/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/355/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/356/
#   inflating: /content/dataset/Face Data/Face Dataset/356/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/356/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/356/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/356/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/357/
#   inflating: /content/dataset/Face Data/Face Dataset/357/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/357/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/357/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/357/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/358/
#   inflating: /content/dataset/Face Data/Face Dataset/358/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/358/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/359/
#   inflating: /content/dataset/Face Data/Face Dataset/359/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/359/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/359/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/36/
#   inflating: /content/dataset/Face Data/Face Dataset/36/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/36/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/360/
#   inflating: /content/dataset/Face Data/Face Dataset/360/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/360/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/361/
#   inflating: /content/dataset/Face Data/Face Dataset/361/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/361/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/361/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/361/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/362/
#   inflating: /content/dataset/Face Data/Face Dataset/362/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/362/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/363/
#   inflating: /content/dataset/Face Data/Face Dataset/363/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/363/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/364/
#   inflating: /content/dataset/Face Data/Face Dataset/364/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/364/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/364/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/364/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/364/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/364/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/365/
#   inflating: /content/dataset/Face Data/Face Dataset/365/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/365/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/366/
#   inflating: /content/dataset/Face Data/Face Dataset/366/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/366/6.jpg
#    creating: /content/dataset/Face Data/Face Dataset/367/
#   inflating: /content/dataset/Face Data/Face Dataset/367/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/367/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/368/
#   inflating: /content/dataset/Face Data/Face Dataset/368/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/368/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/368/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/368/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/368/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/369/
#   inflating: /content/dataset/Face Data/Face Dataset/369/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/369/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/369/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/369/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/37/
#   inflating: /content/dataset/Face Data/Face Dataset/37/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/37/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/37/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/370/
#   inflating: /content/dataset/Face Data/Face Dataset/370/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/370/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/371/
#   inflating: /content/dataset/Face Data/Face Dataset/371/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/371/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/372/
#   inflating: /content/dataset/Face Data/Face Dataset/372/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/372/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/373/
#   inflating: /content/dataset/Face Data/Face Dataset/373/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/373/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/373/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/373/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/373/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/373/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/374/
#   inflating: /content/dataset/Face Data/Face Dataset/374/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/374/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/374/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/375/
#   inflating: /content/dataset/Face Data/Face Dataset/375/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/375/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/376/
#   inflating: /content/dataset/Face Data/Face Dataset/376/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/376/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/377/
#   inflating: /content/dataset/Face Data/Face Dataset/377/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/377/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/377/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/378/
#   inflating: /content/dataset/Face Data/Face Dataset/378/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/378/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/379/
#   inflating: /content/dataset/Face Data/Face Dataset/379/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/379/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/379/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/38/
#   inflating: /content/dataset/Face Data/Face Dataset/38/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/20.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/21.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/22.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/23.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/24.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/25.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/26.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/27.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/28.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/29.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/30.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/31.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/32.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/33.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/34.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/35.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/36.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/37.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/38.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/38/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/380/
#   inflating: /content/dataset/Face Data/Face Dataset/380/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/380/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/381/
#   inflating: /content/dataset/Face Data/Face Dataset/381/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/381/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/382/
#   inflating: /content/dataset/Face Data/Face Dataset/382/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/382/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/383/
#   inflating: /content/dataset/Face Data/Face Dataset/383/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/383/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/384/
#   inflating: /content/dataset/Face Data/Face Dataset/384/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/384/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/385/
#   inflating: /content/dataset/Face Data/Face Dataset/385/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/385/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/386/
#   inflating: /content/dataset/Face Data/Face Dataset/386/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/386/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/387/
#   inflating: /content/dataset/Face Data/Face Dataset/387/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/387/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/388/
#   inflating: /content/dataset/Face Data/Face Dataset/388/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/388/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/388/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/388/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/389/
#   inflating: /content/dataset/Face Data/Face Dataset/389/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/389/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/389/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/39/
#   inflating: /content/dataset/Face Data/Face Dataset/39/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/39/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/39/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/39/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/390/
#   inflating: /content/dataset/Face Data/Face Dataset/390/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/390/2.jpg
# ...
#   inflating: /content/dataset/Face Data/Face Dataset/97/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/97/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/970/
#   inflating: /content/dataset/Face Data/Face Dataset/970/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/970/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/971/
#   inflating: /content/dataset/Face Data/Face Dataset/971/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/971/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/972/
#   inflating: /content/dataset/Face Data/Face Dataset/972/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/972/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/973/
#   inflating: /content/dataset/Face Data/Face Dataset/973/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/973/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/973/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/973/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/974/
#   inflating: /content/dataset/Face Data/Face Dataset/974/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/974/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/975/
#   inflating: /content/dataset/Face Data/Face Dataset/975/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/975/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/976/
#   inflating: /content/dataset/Face Data/Face Dataset/976/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/976/6.jpg
#    creating: /content/dataset/Face Data/Face Dataset/977/
#   inflating: /content/dataset/Face Data/Face Dataset/977/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/977/8.jpg
#    creating: /content/dataset/Face Data/Face Dataset/978/
#   inflating: /content/dataset/Face Data/Face Dataset/978/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/978/7.jpg
#    creating: /content/dataset/Face Data/Face Dataset/979/
#   inflating: /content/dataset/Face Data/Face Dataset/979/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/979/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/979/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/98/
#   inflating: /content/dataset/Face Data/Face Dataset/98/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/98/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/98/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/980/
#   inflating: /content/dataset/Face Data/Face Dataset/980/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/20.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/21.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/22.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/23.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/24.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/25.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/26.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/27.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/28.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/29.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/30.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/31.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/32.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/33.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/34.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/35.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/36.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/37.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/38.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/39.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/40.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/980/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/981/
#   inflating: /content/dataset/Face Data/Face Dataset/981/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/981/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/982/
#   inflating: /content/dataset/Face Data/Face Dataset/982/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/982/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/983/
#   inflating: /content/dataset/Face Data/Face Dataset/983/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/983/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/984/
#   inflating: /content/dataset/Face Data/Face Dataset/984/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/984/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/984/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/985/
#   inflating: /content/dataset/Face Data/Face Dataset/985/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/985/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/985/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/986/
#   inflating: /content/dataset/Face Data/Face Dataset/986/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/986/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/987/
#   inflating: /content/dataset/Face Data/Face Dataset/987/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/987/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/987/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/987/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/987/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/988/
#   inflating: /content/dataset/Face Data/Face Dataset/988/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/988/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/988/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/988/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/988/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/989/
#   inflating: /content/dataset/Face Data/Face Dataset/989/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/989/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/989/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/989/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/989/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/989/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/99/
#   inflating: /content/dataset/Face Data/Face Dataset/99/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/99/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/990/
#   inflating: /content/dataset/Face Data/Face Dataset/990/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/990/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/990/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/990/3.jpg
#    creating: /content/dataset/Face Data/Face Dataset/991/
#   inflating: /content/dataset/Face Data/Face Dataset/991/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/991/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/991/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/991/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/991/4.jpg
#    creating: /content/dataset/Face Data/Face Dataset/992/
#   inflating: /content/dataset/Face Data/Face Dataset/992/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/992/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/992/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/992/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/992/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/992/5.jpg
#    creating: /content/dataset/Face Data/Face Dataset/993/
#   inflating: /content/dataset/Face Data/Face Dataset/993/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/993/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/994/
#   inflating: /content/dataset/Face Data/Face Dataset/994/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/10.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/11.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/12.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/13.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/14.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/15.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/16.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/17.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/18.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/19.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/2.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/20.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/21.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/22.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/23.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/24.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/25.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/26.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/27.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/28.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/29.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/3.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/30.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/31.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/32.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/33.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/34.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/35.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/36.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/37.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/38.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/39.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/4.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/40.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/41.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/42.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/43.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/44.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/45.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/46.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/47.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/5.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/6.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/7.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/8.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/994/9.jpg
#    creating: /content/dataset/Face Data/Face Dataset/995/
#   inflating: /content/dataset/Face Data/Face Dataset/995/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/995/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/996/
#   inflating: /content/dataset/Face Data/Face Dataset/996/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/996/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/997/
#   inflating: /content/dataset/Face Data/Face Dataset/997/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/997/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/997/2.jpg
#    creating: /content/dataset/Face Data/Face Dataset/998/
#   inflating: /content/dataset/Face Data/Face Dataset/998/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/998/1.jpg
#    creating: /content/dataset/Face Data/Face Dataset/999/
#   inflating: /content/dataset/Face Data/Face Dataset/999/0.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/999/1.jpg
#   inflating: /content/dataset/Face Data/Face Dataset/999/2.jpg

# %%
FACE_DATA_PATH = '/content/dataset/Face Data/Face Dataset'
EXTRACTED_FACES_PATH = '/content/dataset/Extracted Faces/Extracted Faces'

# %% [markdown]
# ## Dataset Exploration
# ### Exploring Folder Contents
#
# The purpose of the function below is to gain insights into the dataset we are working with. This function takes a `folder_path` as input and performs the following tasks:
#
# 1. Iterate through subfolders within the specified folder.
# 2. For each subfolder, read the images and collect information about their shapes.
# 3. Calculate the total number of images and the total number of unique people in the dataset.
# 4. Displays the unique image shapes and summary statistics.
#
# This exploration step helps in better understanding the composition of the dataset, which is crucial for data preprocessing and model development.

# %%
def explore_folder(folder_path):
    print(f'Exploring {os.path.basename(folder_path)}')
    image_shapes = []
    num_images = 0
    num_people = 0
    for folder_name in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, folder_name)
        for image_name in os.listdir(subfolder_path):
            image_path = os.path.join(subfolder_path, image_name)
            image = cv2.imread(image_path)
            image_shapes.append(image.shape)
            num_images += 1
        num_people +=1
    print(f'Unique image shapes in: {set(image_shapes)}')
    print(f"Total number of images: {num_images}")
    print(f"Total number of people: {num_people}")
    return image_shapes, num_images, num_people

# %% [markdown]
# Running the `explore_folder` function to analyze the dataset's characteristics.

# %%
explore_folder(FACE_DATA_PATH)
# Out:
# Exploring Face Dataset
# Unique image shapes in: {(250, 250, 3)}
# Total number of images: 8204
# Total number of people: 1680
# ([(250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   (250, 250, 3),
#   ...],
#  8204,
#  1680)

# %%
explore_folder(EXTRACTED_FACES_PATH)
# Out:
# Exploring Extracted Faces
# Unique image shapes in: {(128, 128, 3)}
# Total number of images: 6107
# Total number of people: 1324
# ([(128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   (128, 128, 3),
#   ...],
#  6107,
#  1324)

# %% [markdown]
# The dataset consists of two folders: Face Dataset and Extracted Faces. First one has 8204 (250x250) images of 1680 individuals and second one - 6107 (128, 128) and 1324 respectively. Each image has 3 channels, meaning it is RGB encoded.
#
# Notice the difference in number of images and people in these two folders. We will deal with it later.

# %% [markdown]
# ### Visualizing Sample Images
#
# In this section, we utilize the `visualize_sample_images` function to display a grid of sample images from a specified folder. The primary goal is to provide a visual representation of the dataset's contents and to illustrate the appearance of individuals in the dataset.
#
# This visualization helps us get a glimpse of the dataset's visual diversity and confirms that the images are loaded correctly.

# %%
def visualize_sample_images(folder_path):
    num_images = len(os.listdir(folder_path))
    num_rows = (num_images + 4) // 5
    num_cols = min(num_images, 5)

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 3 * num_rows))

    for i, image_name in enumerate(os.listdir(folder_path)):
        image_path = os.path.join(folder_path, image_name)
        sample_image = cv2.imread(image_path)
        sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)

        row = i // num_cols
        col = i % num_cols

        if num_rows == 1:
              ax = axes[col]
        else:
            ax = axes[row, col]

        ax.imshow(sample_image)
        ax.axis('off')

    for ax in axes.flat[num_images:]:
          ax.remove()

    plt.suptitle(f'Person ID: {os.path.basename(folder_path)}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Let's use the `visualize_sample_images` function to view sample images from a specific person's folder.

# %%
person_id = random.choice(os.listdir(FACE_DATA_PATH))
folder_path = os.path.join(FACE_DATA_PATH, person_id)
print(f'Samples from {os.path.basename(FACE_DATA_PATH)}')
visualize_sample_images(folder_path)
# Out:
# Samples from Face Dataset

# %%
print(f'Samples from {os.path.basename(EXTRACTED_FACES_PATH)}')
if person_id in os.listdir(EXTRACTED_FACES_PATH):
    folder_path = os.path.join(EXTRACTED_FACES_PATH, person_id)
    visualize_sample_images(folder_path)
else:
    print(f'There is no person {person_id} in this folder')
# Out:
# Samples from Extracted Faces
# There is no person 364 in this folder

# %% [markdown]
# ### Creating a Dataset
#
# To prepare our dataset for further model training, we need to create a consolidated output dataset that combines images from the original face dataset and the extracted faces dataset.
#
# The main goal of this step is to increase size of the data. The more data we have - the better!

# %%
DATASET = 'images/output_dataset'
if os.path.exists(DATASET):
    shutil.rmtree(DATASET)
os.makedirs(DATASET)

def copy_to_output_dataset(input_path, output_path):
    for person_folder in os.listdir(input_path):
        person_folder_path = os.path.join(input_path, person_folder)
        if os.path.isdir(person_folder_path):
            output_person_folder = os.path.join(output_path, person_folder)
            if not os.path.exists(output_person_folder):
                os.makedirs(output_person_folder)

            for image_file in os.listdir(person_folder_path):
                if image_file.endswith('.jpg'):
                    src_image_path = os.path.join(person_folder_path, image_file)
                    dst_image_path = os.path.join(output_person_folder, image_file)
                    if os.path.exists(dst_image_path):
                        base, ext = os.path.splitext(dst_image_path)
                        dst_image_path = f"{base}_1{ext}"
                    shutil.copy(src_image_path, dst_image_path)

copy_to_output_dataset(FACE_DATA_PATH, DATASET)
copy_to_output_dataset(EXTRACTED_FACES_PATH, DATASET)

# %%
explore_folder(DATASET);
# Out:
# Exploring output_dataset
# Unique image shapes in: {(250, 250, 3), (128, 128, 3)}
# Total number of images: 14311
# Total number of people: 1680

# %%
visualize_sample_images(os.path.join(DATASET, '10'))

# %% [markdown]
# ## Siamese Neural Network
# ### Generating Triplets
# To train a Siamese network for face recognition, we need to create triplets of images for each training batch. Each triplet consists of an **anchor image** (a sample image of a person), a **positive image** (another image of the same person), and a **negative image** (an image of a different person). These triplets are used to calculate the triplet loss, which encourages the network to learn to differentiate between different individuals.

# %%
def triplets(folder_paths, max_triplets=7):
    anchor_images = []
    positive_images = []
    negative_images = []

    for person_folder in folder_paths:
        images = [os.path.join(person_folder, img)
                  for img in os.listdir(person_folder)]
        num_images = len(images)

        if num_images < 2:
            continue

        random.shuffle(images)

        for _ in range(max(num_images-1, max_triplets)):
            anchor_image = random.choice(images)

            positive_image = random.choice([x for x in images
                                            if x != anchor_image])

            negative_folder = random.choice([x for x in folder_paths
                                             if x != person_folder])

            negative_image = random.choice([os.path.join(negative_folder, img)
                                            for img in os.listdir(negative_folder)])

            anchor_images.append(anchor_image)
            positive_images.append(positive_image)
            negative_images.append(negative_image)

    return anchor_images, positive_images, negative_images

# %% [markdown]
# This code generates triplets by randomly selecting anchor, positive, and negative images, ensuring that the negative image comes from a different person's folder. The number of triplets per person is capped at `max_triplets` to control the training dataset size.

# %%
person_folders = [os.path.join(DATASET, folder_name)
                  for folder_name in os.listdir(DATASET)]

anchors, positives, negatives = triplets(person_folders)

# %% [markdown]
# ### Splitting Triplets
#
# To train a Siamese network effectively, it's essential to have both a training and a validation set of triplets. The training set is used to optimize the model's parameters, while the validation set helps monitor the model's performance and prevent overfitting.

# %%
def split_triplets(anchors,
                   positives,
                   negatives,
                   validation_split=0.2):

    triplets = list(zip(anchors, positives, negatives))

    train_triplets, val_triplets = train_test_split(triplets,
                                                    test_size=validation_split,
                                                    random_state=42)

    return train_triplets, val_triplets

# %%
train_triplets, val_triplets = split_triplets(anchors,
                                              positives,
                                              negatives)
len(train_triplets), len(val_triplets)
# Out:
# (13854, 3464)

# %% [markdown]
# ### Loading and Preprocessing Images
#
# Before using images in a machine learning model, it's essential to preprocess them consistently. This preprocessing typically involves tasks like resizing, color space conversion, and optional dimension expansion.

# %%
def load_and_preprocess_image(image_path, expand_dims=False):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (128, 128))
    if expand_dims:
        image = np.expand_dims(image, axis=0)
    return image

# %% [markdown]
# ### Batch Generator with Data Augmentation
#
# Data augmentation is a common technique used to increase the diversity of training data by applying random transformations to input images. This can help improve the robustness and generalization of machine learning models. In this code block, we define a batch generator for Siamese networks with an option to apply data augmentation.
#
# The generator employs the following data augmentation techniques:
# - Random rotation (up to 10 degrees)
# - Random horizontal and vertical shifts (up to 5% of the image size)
# - Horizontal flipping
# - Random zooming (up to 20%)
#
# The `batch_generator` function takes a list of triplets, a batch size, and an augment flag as input. It shuffles the indices of triplets, applies data augmentation to the anchor, positive, and negative images (if `augment` is True), and yields batches of augmented triplets for training the Siamese network.

# %%
def batch_generator(triplets, batch_size=32, augment=True):
    total_triplets = len(triplets)
    random_indices = list(range(total_triplets))
    random.shuffle(random_indices)

    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=True,
        zoom_range=0.2
    )

    for i in range(0, total_triplets, batch_size):
        batch_indices = random_indices[i:i + batch_size]
        batch_triplets = [triplets[j] for j in batch_indices]

        anchor_batch = []
        positive_batch = []
        negative_batch = []

        for triplet in batch_triplets:
            anchor, positive, negative = triplet

            anchor_image = load_and_preprocess_image(anchor)
            positive_image = load_and_preprocess_image(positive)
            negative_image = load_and_preprocess_image(negative)

            if augment:
                anchor_image = datagen.random_transform(anchor_image)
                positive_image = datagen.random_transform(positive_image)
                negative_image = datagen.random_transform(negative_image)

            anchor_batch.append(anchor_image)
            positive_batch.append(positive_image)
            negative_batch.append(negative_image)

        yield [np.array(anchor_batch),
               np.array(positive_batch),
               np.array(negative_batch)]

# %% [markdown]
# ### Visualizing Triplets
# The `visualize_triplets` function takes a batch of triplets as input and displays the anchor, positive, and negative images side by side in a single row. Visualizing triplets can help us to verify that the data is loaded and preprocessed correctly and gain insights into the face recognition process.

# %%
def visualize_triplets(triplets):
    anchor_batch, positive_batch, negative_batch = triplets

    for i in range(len(anchor_batch)):
        plt.figure(figsize=(15, 5))

        plt.subplot(1, 3, 1)
        plt.title("Anchor")
        plt.imshow(anchor_batch[i])
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.title("Positive")
        plt.imshow(positive_batch[i])
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.title("Negative")
        plt.imshow(negative_batch[i])
        plt.axis('off')

        plt.show()

# %% [markdown]
# Let's visualize a random batch.

# %%
example_triplets = [next(batch_generator(train_triplets, 5))]
visualize_triplets(example_triplets[0])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Defining the Embedding Model
#
# The `get_embedding` function serves the purpose of creating the embedding model that extracts meaningful representations (embeddings) from input images. In this context, the embedding model plays a crucial role in face recognition, as it transforms images into a feature space where similar faces are close together and dissimilar faces are farther apart.
#
# This function utilizes the **EfficientNetB7** architecture, a powerful convolutional neural network pretrained on ImageNet, as the base model. It then adds additional layers to fine-tune the model for the face recognition task.

# %%
def get_embedding(input_shape, num_layers_to_unfreeze=25):
    base_model = EfficientNetB7(weights='imagenet',
                                input_shape=input_shape,
                                include_top=False,
                                pooling='avg')

    for i in range(len(base_model.layers)-num_layers_to_unfreeze):
        base_model.layers[i].trainable = False

    embedding = tf.keras.models.Sequential([
        base_model,
        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dense(128)
    ], name='Embedding')

    return embedding

# %%
input_shape = (128, 128, 3)

embedding = get_embedding(input_shape)
embedding.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 1s 0us/step
# Model: "Embedding"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb7 (Functional  (None, 2560)              64097687
#  )
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 512)               1311232
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_3 (Dense)             (None, 128)               16512
#
# =================================================================
# Total params: 65593239 (250.22 MB)
# Trainable params: 12413600 (47.35 MB)
# Non-trainable params: 53179639 (202.86 MB)
# _________________________________________________________________

# %% [markdown]
# ### Siamese Network Architecture
#
# In this code block, we define the architecture of a Siamese Network. The goal is to minimize the distance between anchor and positive embeddings while maximizing the distance between anchor and negative embeddings.
#
# Here's a breakdown of the key components:
#
# 1. **DistanceLayer**: This custom Keras layer computes the Euclidean distances between the anchor and positive embeddings (ap_distance) and between the anchor and negative embeddings (an_distance). These distances will be used to calculate the triplet loss during training.
#
# $$d_{AP} = \sum_{i=1}^{N} (a_i - p_i)^2, d_{AN} = \sum_{i=1}^{N} (a_i - n_i)^2$$
#
# where $a_i$, $p_i$, and $n_i$ are the elements of the anchor, positive, and negative embeddings, respectively.
#
#
# 2. **Inputs**: Three input tensors (`anchor_input`, `positive_input`, and `negative_input`) are defined, representing the anchor, positive, and negative images, respectively. The `shape` of these inputs corresponds to the desired input image shape (128x128x3).
#
# 3. **Embedding Model**: The `embedding` model is applied to each input image to obtain their embeddings.
#
# 4. **Distance Computation**: The `DistanceLayer` layer computes the distances between the embeddings obtained from the anchor, positive, and negative images.
#
# 5. **Siamese Network**: Finally, the Siamese network is defined as a Keras model that takes the three input images and outputs the computed distances. This network serves as the core component for training and evaluating the triplet loss.

# %%
@tf.keras.saving.register_keras_serializable()
class DistanceLayer(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative):
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        an_distance = tf.reduce_sum(tf.square(anchor - negative), -1)
        return ap_distance, an_distance

anchor_input = Input(name='anchor', shape=input_shape)
positive_input = Input(name='positive', shape=input_shape)
negative_input = Input(name='negative', shape=input_shape)

distances = DistanceLayer()(
    embedding(preprocess_input(anchor_input)),
    embedding(preprocess_input(positive_input)),
    embedding(preprocess_input(negative_input))
)

siamese_net = Model(
    inputs=[anchor_input,
            positive_input,
            negative_input],
    outputs=distances
)

# %%
plot_model(siamese_net, show_shapes=True, show_layer_names=True)

# %%
siamese_net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  anchor (InputLayer)         [(None, 128, 128, 3)]        0         []
#
#  positive (InputLayer)       [(None, 128, 128, 3)]        0         []
#
#  negative (InputLayer)       [(None, 128, 128, 3)]        0         []
#
#  Embedding (Sequential)      (None, 128)                  6559323   ['anchor[0][0]',
#                                                           9          'positive[0][0]',
#                                                                      'negative[0][0]']
#
#  distance_layer (DistanceLa  ((None,),                    0         ['Embedding[0][0]',
#  yer)                         (None,))                               'Embedding[1][0]',
#                                                                      'Embedding[2][0]']
#
# ==================================================================================================
# Total params: 65593239 (250.22 MB)
# Trainable params: 12413600 (47.35 MB)
# Non-trainable params: 53179639 (202.86 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Custom Siamese Model
#
# In this code block, we define a custom Keras model called `SiameseModel` designed for training and evaluating Siamese Networks. The Siamese Model wraps the Siamese network defined earlier and includes custom training and evaluation logic for the face recognition task.
#
# Here's a breakdown of the key components and functionalities:
#
# 1. **Initialization**: The `SiameseModel` class is initialized with the Siamese network (`siamese_net`) and a margin value (`margin`) for the triplet loss function. It also creates trackers for loss and accuracy metrics.
#
# 2. **`call` Method**: The `call` method defines the forward pass of the Siamese Model. It takes a batch of triplets as input and passes it through the Siamese network, returning the computed distances between anchor-positive and anchor-negative pairs.
#
# 3. **Custom Training Logic (`train_step`)**: The `train_step` method is called during training. It computes the triplet loss using the distances obtained from the Siamese network. It then computes gradients and applies them to update the Siamese network's trainable weights. Additionally, it updates the loss and accuracy trackers.
#
# 4. **Custom Evaluation Logic (`test_step`)**: The `test_step` method is called during evaluation. It computes the triplet loss and accuracy in a similar way to the training step but without backpropagation.
#
# 5. **Loss Calculation (`_compute_loss`)**: This private method calculates the triplet loss based on the anchor-positive and anchor-negative distances. The loss is defined as the difference between these distances, subject to a margin, ensuring that similar pairs have smaller distances.
#
# 6. **Accuracy Calculation (`_compute_accuracy`)**: This private method computes the accuracy by comparing the anchor-positive and anchor-negative distances. It counts how often the anchor-positive distance is smaller than the anchor-negative distance.
#
# 7. **Metrics Property**: The `metrics` property returns a list of loss and accuracy metrics for tracking during training and evaluation.
#
# 8. **Serialization Methods**: The `get_config` and `from_config` methods are provided for model serialization. They enable saving and loading the Siamese Model's configuration, including its custom objects ([reference](https://www.tensorflow.org/guide/keras/serialization_and_saving))
#
# This code block is a crucial part of the project, as it defines the model that learns to recognize faces based on learned embeddings and the triplet loss function.

# %%
@tf.keras.saving.register_keras_serializable()
class SiameseModel(Model):
    def __init__(self, siamese_net, margin=0.5):
        super().__init__()
        self.siamese_net = siamese_net
        self.margin = margin
        self.loss_tracker = Mean(name='loss')
        self.accuracy_tracker = Mean(name='accuracy')

    def call(self, inputs):
        return self.siamese_net(inputs)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)

        gradients = tape.gradient(loss, self.siamese_net.trainable_weights)

        self.optimizer.apply_gradients(
            zip(gradients, self.siamese_net.trainable_weights)
        )

        self.loss_tracker.update_state(loss)

        accuracy = self._compute_accuracy(data)
        self.accuracy_tracker.update_state(accuracy)

        return {'loss': self.loss_tracker.result(),
                'accuracy': self.accuracy_tracker.result()}

    def test_step(self, data):
        loss = self._compute_loss(data)

        self.loss_tracker.update_state(loss)

        accuracy = self._compute_accuracy(data)
        self.accuracy_tracker.update_state(accuracy)

        return {'loss': self.loss_tracker.result(),
                'accuracy': self.accuracy_tracker.result()}

    def _compute_loss(self, data):
        ap_distance, an_distance = self.siamese_net(data)

        loss = ap_distance - an_distance
        loss = tf.maximum(loss + self.margin, .0)
        return loss

    def _compute_accuracy(self, data):
        ap_distance, an_distance = self.siamese_net(data)
        accuracy = tf.reduce_mean(tf.cast(ap_distance < an_distance,
                                          tf.float32))
        return accuracy

    @property
    def metrics(self):
        return [self.loss_tracker, self.accuracy_tracker]

    def get_config(self):
        base_config = super().get_config()
        config = {
            'siamese_net': tf.keras.saving.serialize_keras_object(self.siamese_net),
            'margin': tf.keras.saving.serialize_keras_object(self.margin),
            'loss_tracker': tf.keras.saving.serialize_keras_object(self.loss_tracker),
            'accuracy_tracker': tf.keras.saving.serialize_keras_object(self.accuracy_tracker),
        }
        return {**base_config, **config}

    @classmethod
    def from_config(cls, config):
        config['siamese_net'] = tf.keras.saving.deserialize_keras_object(config.pop('siamese_net'))
        config['margin'] = tf.keras.saving.deserialize_keras_object(config.pop('margin'))
        config['loss_tracker'] = tf.keras.saving.deserialize_keras_object(config.pop('loss_tracker'))
        config['accuracy_tracker'] = tf.keras.saving.deserialize_keras_object(config.pop('accuracy_tracker'))
        return cls(**config)

# %% [markdown]
# ### Training the Siamese Model
#
# The next code block defines a function `train_model` for training a Siamese model on face recognition using triplet loss.
#
# 1. **Function Parameters**: The function takes several parameters, including the Siamese model (`model`), training triplets (`train_triplets`), the number of training epochs (`epochs`), batch size (`batch_size`), validation triplets (`val_triplets`), and early stopping parameters (`patience` and `delta`).
#
# 2. **Training Loop**: The code implements a training loop that runs for the specified number of epochs. During each epoch, it trains the Siamese model using training triplets and evaluates it on validation triplets.
#
# 3. **Progress Bar**: The code uses the `tqdm` library to create progress bars for training and validation. This provides a visual indication of the training progress and the current loss and accuracy.
#
# 4. **Batch Training**: The training data is divided into batches using the `batch_generator` function. The model is updated with each batch using the `train_on_batch` method.
#
# 5. **Loss and Accuracy Tracking**: The code tracks training and validation loss as well as accuracy for each epoch and stores them in a `history` dictionary.
#
# 6. **Model Checkpoint**: The best model weights are saved when the validation accuracy improves.
#
# 7. **Early Stopping**: Early stopping prevents overfitting by stopping training if the validation loss does not improve significantly (`delta`) for a specified number of epochs (`patience`).
#
# 8. **Return Values**: The function returns the trained model and a history dictionary containing loss and accuracy values for each epoch.

# %%
def train_model(model,
                train_triplets,
                epochs,
                batch_size,
                val_triplets,
                patience,
                delta=0.0001):

    best_val_accuracy = 0
    best_val_loss = float('inf')
    temp_patience = patience
    history = {
        'loss': [],
        'val_loss': [],
        'accuracy': [],
        'val_accuracy': []
    }

    train_steps_per_epoch = math.ceil(len(train_triplets) / batch_size)
    val_steps_per_epoch = math.ceil(len(val_triplets) / batch_size)

    for epoch in range(epochs):
        print(f'Epoch {epoch+1}/{epochs}')
        train_loss = 0.
        train_accuracy = 0.
        val_loss = 0.
        val_accuracy = 0.

        with tqdm(total=train_steps_per_epoch, desc='Training') as pbar:
            for batch in batch_generator(train_triplets, batch_size=batch_size):
                loss, accuracy = model.train_on_batch(batch)
                train_loss += loss
                train_accuracy += accuracy

                pbar.update()
                pbar.set_postfix({'Loss': loss, 'Accuracy': accuracy})

        with tqdm(total=val_steps_per_epoch, desc='Validation') as pbar:
            for batch in batch_generator(val_triplets, batch_size=batch_size):
                loss, accuracy = model.test_on_batch(batch)
                val_loss += loss
                val_accuracy += accuracy

                pbar.update()
                pbar.set_postfix({'Loss': loss, 'Accuracy': accuracy})

        train_loss /= train_steps_per_epoch
        train_accuracy /= train_steps_per_epoch
        val_loss /= val_steps_per_epoch
        val_accuracy /= val_steps_per_epoch

        history['loss'].append(train_loss)
        history['accuracy'].append(train_accuracy)
        history['val_loss'].append(val_loss)
        history['val_accuracy'].append(val_accuracy)

        print(f'\nTrain Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
        print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}\n')

        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            model.layers[0].layers[3].save_weights('/content/drive/MyDrive/Colab Notebooks/Facial Recognition with Siamese Network/best_model.weights.h5')

        if val_loss - best_val_loss > delta:
            temp_patience -= 1
            if temp_patience == 0:
                print('Early stopping: Validation loss did not improve.')
                break
        else:
            best_val_loss = val_loss
            temp_patience = patience

    return model, history

# %% [markdown]
# #### Finally, let's train the model!

# %%
siamese_model = SiameseModel(siamese_net)
siamese_model.compile(optimizer=Adam(0.0001))

siamese_model, history = train_model(siamese_model,
                                     train_triplets=train_triplets,
                                     epochs=30,
                                     batch_size=64,
                                     val_triplets=val_triplets,
                                     patience=2)
# Out:
# Epoch 1/30
# Training: 100%|██████████| 217/217 [11:21<00:00,  3.14s/it, Loss=0.322, Accuracy=0.733]
# Validation: 100%|██████████| 55/55 [03:07<00:00,  3.41s/it, Loss=0.337, Accuracy=0.625]
# Train Loss: 0.2344, Train Accuracy: 0.8414
# Validation Loss: 0.1785, Validation Accuracy: 0.8480
#
# Epoch 2/30
# Training: 100%|██████████| 217/217 [08:47<00:00,  2.43s/it, Loss=0.111, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:09<00:00,  2.35s/it, Loss=0.213, Accuracy=0.875]
# Train Loss: 0.1477, Train Accuracy: 0.9006
# Validation Loss: 0.1520, Validation Accuracy: 0.8810
#
# Epoch 3/30
# Training: 100%|██████████| 217/217 [08:48<00:00,  2.44s/it, Loss=0.15, Accuracy=0.867]
# Validation: 100%|██████████| 55/55 [02:10<00:00,  2.38s/it, Loss=0.179, Accuracy=0.875]
# Train Loss: 0.1242, Train Accuracy: 0.9187
# Validation Loss: 0.1372, Validation Accuracy: 0.8875
#
# Epoch 4/30
# Training: 100%|██████████| 217/217 [08:45<00:00,  2.42s/it, Loss=0.0948, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:07<00:00,  2.31s/it, Loss=0.359, Accuracy=0.625]
# Train Loss: 0.1053, Train Accuracy: 0.9341
# Validation Loss: 0.1367, Validation Accuracy: 0.8935
#
# Epoch 5/30
# Training: 100%|██████████| 217/217 [08:48<00:00,  2.44s/it, Loss=0.0641, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:10<00:00,  2.37s/it, Loss=0.0771, Accuracy=0.875]
# Train Loss: 0.0885, Train Accuracy: 0.9501
# Validation Loss: 0.1319, Validation Accuracy: 0.8938
#
# Epoch 6/30
# Training: 100%|██████████| 217/217 [08:59<00:00,  2.49s/it, Loss=0.0719, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:08<00:00,  2.33s/it, Loss=0.0387, Accuracy=1]
# Train Loss: 0.0803, Train Accuracy: 0.9554
# Validation Loss: 0.1186, Validation Accuracy: 0.9085
#
# Epoch 7/30
# Training: 100%|██████████| 217/217 [08:52<00:00,  2.46s/it, Loss=0.12, Accuracy=0.9]
# Validation: 100%|██████████| 55/55 [02:06<00:00,  2.31s/it, Loss=0, Accuracy=1]
# Train Loss: 0.0671, Train Accuracy: 0.9625
# Validation Loss: 0.1133, Validation Accuracy: 0.9080
#
# Epoch 8/30
# Training: 100%|██████████| 217/217 [08:52<00:00,  2.46s/it, Loss=0.0651, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:05<00:00,  2.27s/it, Loss=0.0368, Accuracy=1]
# Train Loss: 0.0605, Train Accuracy: 0.9685
# Validation Loss: 0.1323, Validation Accuracy: 0.8969
#
# Epoch 9/30
# Training: 100%|██████████| 217/217 [08:52<00:00,  2.46s/it, Loss=0.0615, Accuracy=0.967]
# Validation: 100%|██████████| 55/55 [02:07<00:00,  2.32s/it, Loss=0.0371, Accuracy=1]
# Train Loss: 0.0537, Train Accuracy: 0.9732
# Validation Loss: 0.1234, Validation Accuracy: 0.9080
#
# Early stopping: Validation loss did not improve.

# %% [markdown]
# ## Model Evaluation
# ### Training Visualization
#
# After the training is complete, let's create a visual representation of the model's training progress.

# %%
plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')

plt.subplot(122)
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')

plt.show()

# %% [markdown]
# We can observe how the loss decreases and accuracy increases over training epochs. The comparison between training and validation curves helps identify potential overfitting or underfitting issues. In an ideal scenario, both loss curves should decrease, and accuracy curves should increase over time, but we can see that validation metrics don't show so much improvement, meaning that the model generalizations are not perfect.

# %% [markdown]
# ### Calculating Cosine Similarity
#
# These similarity scores can help evaluate the effectiveness of the Siamese model. A higher positive similarity indicates that the anchor and positive samples are more similar, which is expected. Conversely, a lower negative similarity indicates that the anchor and negative samples are less similar, which is also expected.
#
# Let's compute and compare cosine similarity between embeddings of anchor, positive, and negative samples.

# %%
sample = next(batch_generator(val_triplets, 1))

anchor, positive, negative = sample
anchor_embedding, positive_embedding, negative_embedding = (
    embedding(preprocess_input(anchor)),
    embedding(preprocess_input(positive)),
    embedding(preprocess_input(negative))
)

cosine_similarity = CosineSimilarity()

positive_similarity = cosine_similarity(anchor_embedding, positive_embedding)
print(f'Positive similarity: {positive_similarity}')

negative_similarity = cosine_similarity(anchor_embedding, negative_embedding)
print(f'Negative similarity: {negative_similarity}')
# Out:
# Positive similarity: 0.9046266078948975
# Negative similarity: 0.8692831993103027

# %% [markdown]
# The positive similarity score is close to 1.0, which indicates a very high similarity between the anchor image and the positive image in the pair.
# The negative similarity score is also quite high but slightly lower than the positive similarity score. This score indicates that the anchor and negative images in the pair are somewhat similar but still dissimilar.  In the context of a Siamese network for tasks like face recognition, this suggests that while the anchor and negative images might share some features, they are still distinguishable from each other.

# %%
siamese_model.save("/content/drive/MyDrive/Colab Notebooks/Facial Recognition with Siamese Network/saved_siamese_model.keras")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py:164: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   saving_lib.save_model(model, filepath)
